# %%
# !pip install ultralytics opencv-python
# Out:
# Requirement already satisfied: ultralytics in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (8.3.231)
# Requirement already satisfied: opencv-python in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy>=1.23.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (2.32.5)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (2.9.1+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (0.24.1+cpu)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: six>=1.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load model
model = YOLO("yolo11s.pt")

# Read image
img = cv2.imread("Amazon Background.jpg")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Inference
result = model(img_rgb)[0]

# Annotated image
annotated = result.plot()

# Show inside notebook
plt.imshow(annotated)
plt.axis("off")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11s.pt to 'yolo11s.pt': 100% ━━━━━━━━━━━━ 18.4MB 5.8MB/s 3.2s3.1s<0.1sss7.7s
#
# 0: 384x640 (no detections), 267.6ms
# Speed: 30.2ms preprocess, 267.6ms inference, 15.1ms postprocess per image at shape (1, 3, 384, 640)
# (np.float64(-0.5), np.float64(1279.5), np.float64(719.5), np.float64(-0.5))

# %%
# !pip install notebook opencv-python ultralytics
# Out:
# Requirement already satisfied: notebook in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (7.4.5)
# Requirement already satisfied: opencv-python in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (4.12.0.88)
# Requirement already satisfied: ultralytics in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (8.3.231)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from notebook) (2.16.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from notebook) (4.4.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from notebook) (6.5.1)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.8.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.21.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.0.15)
# Requirement already satisfied: pyzmq>=24 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: traitlets>=5.6.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (6.31.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.2.5)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (80.9.0)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook) (2.2.1)
# Requirement already satisfied: certifi in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (1.0.9)
# Requirement already satisfied: idna in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.25.0)
# Requirement already satisfied: requests>=2.31 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.32.5)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from opencv-python) (2.2.6)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (3.10.7)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (2.9.1+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (0.24.1+cpu)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (1.35.2)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (1.8.16)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (8.30.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (1.6.0)
# Requirement already satisfied: decorator in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (2.19.2)
# Requirement already satisfied: stack-data in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.6.3)
# Requirement already satisfied: colorama in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.4.0->notebook) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.28.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (4.5.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (311)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.2.1)
# Requirement already satisfied: rfc3339-validator in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: pyparsing>=3 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: beautifulsoup4 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.20.0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from polars>=0.20.0->ultralytics) (1.35.2)
# Requirement already satisfied: six>=1.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: filelock in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (3.0.0)
# Requirement already satisfied: pure_eval in c:\users\ayushi\anaconda3\envs\tfenv\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab<4.5,>=4.4.5->notebook) (0.2.3)

# %%
from ultralytics import YOLO
import cv2
from IPython.display import display, clear_output
import matplotlib.pyplot as plt

model = YOLO("yolo11s.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    results = model(frame)[0]
    annotated = results.plot()

    # Convert BGR → RGB
    annotated = cv2.cvtColor(annotated, cv2.COLOR_BGR2RGB)

    clear_output(wait=True)
    plt.imshow(annotated)
    plt.axis("off")
    display(plt.gcf())

cap.release()
# Out:
# 0: 480x640 1 person, 1 bottle, 286.1ms
# Speed: 4.2ms preprocess, 286.1ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
